# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
training = "dataset/training"
test = "dataset/test"

# %%
type(training)
# Out:
# str

# %%
import pathlib

data = pathlib.Path(training)
test = pathlib.Path(test)

# %%
type(data)
# Out:
# pathlib.PosixPath

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(150, 150),
  batch_size=32)
# Out:
# Found 934 files belonging to 3 classes.
# Using 748 files for training.
# 2022-04-12 15:44:58.448963: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(150, 150),
  batch_size=32)
# Out:
# Found 934 files belonging to 3 classes.
# Using 186 files for validation.

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
  test,
  image_size=(150, 150),
  batch_size=32)
# Out:
# Found 300 files belonging to 3 classes.

# %%
print("Number of training samples: %d" % tf.data.experimental.cardinality(train_ds))
print("Number of validation samples: %d" % tf.data.experimental.cardinality(val_ds))
print("Number of test samples: %d" % tf.data.experimental.cardinality(test_ds))
# Out:
# Number of training samples: 24
# Number of validation samples: 6
# Number of test samples: 10

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['perfect', 'shoo', 'what']

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 150, 150, 3)
# (32,)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
from tensorflow import keras
from tensorflow.keras import layers

data_augmentation = keras.Sequential(
    [layers.RandomFlip("horizontal"), layers.RandomRotation(0.1),]
)

# %%
import numpy as np

for images, labels in train_ds.take(1):
    plt.figure(figsize=(10, 10))
    first_image = images[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image = data_augmentation(
            tf.expand_dims(first_image, 0), training=True
        )
        plt.imshow(augmented_image[0].numpy().astype("int32"))
        plt.title(class_names[labels[0]])
        plt.axis("off")
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faf2a503b90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faf2a503b90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faf2af1ed40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faf2af1ed40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faf2932dd40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faf2932dd40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faf26425290> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faf26425290> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faf265a9680> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faf265a9680> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faf2a519d40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faf2a519d40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faf26449d40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faf26449d40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faf2a78fb90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faf2a78fb90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faf2a71cd40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faf2a71cd40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs

# %%
base_model = keras.applications.Xception(
    weights="imagenet",  # Load weights pre-trained on ImageNet.
    input_shape=(150, 150, 3),
    include_top=False,
)  # Do not include the ImageNet classifier at the top.

# Freeze the base_model
base_model.trainable = False

# Create new model on top
inputs = keras.Input(shape=(150, 150, 3))
x = data_augmentation(inputs)  # Apply random data augmentation

# Pre-trained Xception weights requires that input be scaled
# from (0, 255) to a range of (-1., +1.), the rescaling layer
# outputs: `(inputs * scale) + offset`
scale_layer = keras.layers.Rescaling(scale=1 / 127.5, offset=-1)
x = scale_layer(x)

# The base model contains batchnorm layers. We want to keep them in inference mode
# when we unfreeze the base model for fine-tuning, so we make sure that the
# base_model is running in inference mode here.
x = base_model(x, training=False)
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dropout(0.2)(x)  # Regularize with dropout
outputs = keras.layers.Dense(3)(x)
model = keras.Model(inputs, outputs)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  sequential (Sequential)     (None, 150, 150, 3)       0
#
#  rescaling (Rescaling)       (None, 150, 150, 3)       0
#
#  xception (Functional)       (None, 5, 5, 2048)        20861480
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 3)                 6147
#
# =================================================================
# Total params: 20,867,627
# Trainable params: 6,147
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

epochs = 20
model.fit(train_ds, epochs=epochs, validation_data=val_ds)
# Out:
# Epoch 1/20
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7faf2a3745f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7faf2a3745f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# 24/24 [==============================] - ETA: 0s - loss: 0.7190 - accuracy: 0.7433WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7faf150f7e60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7faf150f7e60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 24/24 [==============================] - 24s 876ms/step - loss: 0.7190 - accuracy: 0.7433 - val_loss: 0.3978 - val_accuracy: 0.9355
# Epoch 2/20
# 24/24 [==============================] - 21s 881ms/step - loss: 0.3063 - accuracy: 0.9439 - val_loss: 0.2206 - val_accuracy: 0.9785
# Epoch 3/20
# 24/24 [==============================] - 21s 889ms/step - loss: 0.1826 - accuracy: 0.9719 - val_loss: 0.1569 - val_accuracy: 0.9839
# Epoch 4/20
# 24/24 [==============================] - 22s 902ms/step - loss: 0.1476 - accuracy: 0.9799 - val_loss: 0.1114 - val_accuracy: 1.0000
# Epoch 5/20
# 24/24 [==============================] - 22s 906ms/step - loss: 0.0969 - accuracy: 0.9947 - val_loss: 0.0932 - val_accuracy: 0.9946
# Epoch 6/20
# 24/24 [==============================] - 21s 890ms/step - loss: 0.1001 - accuracy: 0.9893 - val_loss: 0.0777 - val_accuracy: 1.0000
# Epoch 7/20
# 24/24 [==============================] - 21s 881ms/step - loss: 0.0789 - accuracy: 0.9933 - val_loss: 0.0619 - val_accuracy: 1.0000
# Epoch 8/20
# 24/24 [==============================] - 21s 888ms/step - loss: 0.0686 - accuracy: 0.9933 - val_loss: 0.0607 - val_accuracy: 1.0000
# Epoch 9/20
# 24/24 [==============================] - 22s 922ms/step - loss: 0.0588 - accuracy: 0.9947 - val_loss: 0.0498 - val_accuracy: 1.0000
# Epoch 10/20
# 24/24 [==============================] - 21s 889ms/step - loss: 0.0534 - accuracy: 0.9906 - val_loss: 0.0450 - val_accuracy: 1.0000
# Epoch 11/20
# 24/24 [==============================] - 23s 955ms/step - loss: 0.0499 - accuracy: 0.9960 - val_loss: 0.0431 - val_accuracy: 1.0000
# Epoch 12/20
# 24/24 [==============================] - 22s 900ms/step - loss: 0.0433 - accuracy: 0.9987 - val_loss: 0.0389 - val_accuracy: 1.0000
# Epoch 13/20
# 24/24 [==============================] - 22s 915ms/step - loss: 0.0395 - accuracy: 0.9973 - val_loss: 0.0363 - val_accuracy: 1.0000
# Epoch 14/20
# 24/24 [==============================] - 21s 896ms/step - loss: 0.0315 - accuracy: 0.9987 - val_loss: 0.0291 - val_accuracy: 1.0000
# Epoch 15/20
# 24/24 [==============================] - 21s 891ms/step - loss: 0.0296 - accuracy: 1.0000 - val_loss: 0.0291 - val_accuracy: 1.0000
# Epoch 16/20
# 24/24 [==============================] - 22s 905ms/step - loss: 0.0323 - accuracy: 0.9973 - val_loss: 0.0247 - val_accuracy: 1.0000
# Epoch 17/20
# 24/24 [==============================] - 22s 911ms/step - loss: 0.0265 - accuracy: 0.9987 - val_loss: 0.0246 - val_accuracy: 1.0000
# Epoch 18/20
# 24/24 [==============================] - 22s 918ms/step - loss: 0.0282 - accuracy: 0.9973 - val_loss: 0.0214 - val_accuracy: 1.0000
# Epoch 19/20
# 24/24 [==============================] - 21s 881ms/step - loss: 0.0219 - accuracy: 1.0000 - val_loss: 0.0255 - val_accuracy: 1.0000
# Epoch 20/20
# 24/24 [==============================] - 21s 893ms/step - loss: 0.0252 - accuracy: 0.9973 - val_loss: 0.0201 - val_accuracy: 1.0000

# %%
model.evaluate(test_ds)
# Out:
# 10/10 [==============================] - 6s 598ms/step - loss: 0.0705 - accuracy: 0.9833
# [0.07050890475511551, 0.9833333492279053]

# %%
loss, acc = model.evaluate(test_ds, verbose=0)

# %%
print(loss)
# Out:
# 1.100480556488037

# %%
print(acc)
# Out:
# 0.3333333432674408

# %%
upload = "images/what.jpg"

img = tf.keras.utils.load_img(
    upload, target_size=(150, 150)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) 

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 49ms/step
# This image most likely belongs to what with a 88.76 percent confidence.

# %%
model.save("pre_trained")
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x7faef423fcb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x7faef423fcb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x7faef5033710> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x7faef5033710> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 40). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: pre_trained/assets
# INFO:tensorflow:Assets written to: pre_trained/assets

# %%
# Unfreeze the base_model. Note that it keeps running in inference mode
# since we passed `training=False` when calling it. This means that
# the batchnorm layers will not update their batch statistics.
# This prevents the batchnorm layers from undoing all the training
# we've done so far.
base_model.trainable = True
model.summary()

model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

epochs = 10
model.fit(train_ds, epochs=epochs, validation_data=val_ds)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  sequential (Sequential)     (None, 150, 150, 3)       0
#
#  rescaling (Rescaling)       (None, 150, 150, 3)       0
#
#  xception (Functional)       (None, 5, 5, 2048)        20861480
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 3)                 6147
#
# =================================================================
# Total params: 20,867,627
# Trainable params: 20,813,099
# Non-trainable params: 54,528
# _________________________________________________________________
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7faefc79ae60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7faefc79ae60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7faefc79ae60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# 24/24 [==============================] - ETA: 0s - loss: 3.2323 - accuracy: 0.3971WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7faef805b680> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7faef805b680> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7faef805b680> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 24/24 [==============================] - 84s 3s/step - loss: 3.2323 - accuracy: 0.3971 - val_loss: 1.0969 - val_accuracy: 0.4462
# Epoch 2/10
# 24/24 [==============================] - 81s 3s/step - loss: 1.0970 - accuracy: 0.3917 - val_loss: 1.0961 - val_accuracy: 0.4462
# Epoch 3/10
# 24/24 [==============================] - 73s 3s/step - loss: 1.0964 - accuracy: 0.3917 - val_loss: 1.0948 - val_accuracy: 0.4462
# Epoch 4/10
# 24/24 [==============================] - 73s 3s/step - loss: 1.0959 - accuracy: 0.3917 - val_loss: 1.0934 - val_accuracy: 0.4462
# Epoch 5/10
# 24/24 [==============================] - 73s 3s/step - loss: 1.0952 - accuracy: 0.3917 - val_loss: 1.0921 - val_accuracy: 0.4462
# Epoch 6/10
# 24/24 [==============================] - 76s 3s/step - loss: 1.0947 - accuracy: 0.3917 - val_loss: 1.0910 - val_accuracy: 0.4462
# Epoch 7/10
# 24/24 [==============================] - 74s 3s/step - loss: 1.0942 - accuracy: 0.3917 - val_loss: 1.0899 - val_accuracy: 0.4462
# Epoch 8/10
# 24/24 [==============================] - 73s 3s/step - loss: 1.0937 - accuracy: 0.3917 - val_loss: 1.0888 - val_accuracy: 0.4462
# Epoch 9/10
# 24/24 [==============================] - 73s 3s/step - loss: 1.0934 - accuracy: 0.3917 - val_loss: 1.0876 - val_accuracy: 0.4462
# Epoch 10/10
# 24/24 [==============================] - 73s 3s/step - loss: 1.0931 - accuracy: 0.3917 - val_loss: 1.0872 - val_accuracy: 0.4462
