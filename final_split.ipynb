# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image

# %%
training = "dataset/training"
test = "dataset/test"

# %%
import pathlib

data = pathlib.Path(training)
test_ds = pathlib.Path(test)

# %%
image_count = len(list(data.glob('*/*.jpg')))
print(image_count)
# Out:
# 934

# %%
image_count = len(list(test_ds.glob('*/*.jpg')))
print(image_count)
# Out:
# 300

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 934 files belonging to 3 classes.
# Using 748 files for training.
# 2022-04-12 12:23:08.380677: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 934 files belonging to 3 classes.
# Using 186 files for validation.

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
  test_ds,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 300 files belonging to 3 classes.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['perfect', 'shoo', 'what']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 180, 180, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
#my_callbacks = [tf.keras.callbacks.ModelCheckpoint("my_model_{epoch}", monitor='accuracy', save_best_only=True, verbose=1)]

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 3,989,027
# Trainable params: 3,989,027
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7faa60c9f9e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7faa60c9f9e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 24/24 [==============================] - ETA: 0s - loss: 1.4810 - accuracy: 0.3623WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7faa606d8cb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7faa606d8cb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 24/24 [==============================] - 8s 293ms/step - loss: 1.4810 - accuracy: 0.3623 - val_loss: 1.0465 - val_accuracy: 0.4462
# Epoch 2/20
# 24/24 [==============================] - 7s 272ms/step - loss: 0.9667 - accuracy: 0.5027 - val_loss: 0.8375 - val_accuracy: 0.6505
# Epoch 3/20
# 24/24 [==============================] - 7s 278ms/step - loss: 0.7031 - accuracy: 0.7045 - val_loss: 0.6489 - val_accuracy: 0.7097
# Epoch 4/20
# 24/24 [==============================] - 7s 275ms/step - loss: 0.5192 - accuracy: 0.7955 - val_loss: 0.6090 - val_accuracy: 0.7581
# Epoch 5/20
# 24/24 [==============================] - 9s 382ms/step - loss: 0.4030 - accuracy: 0.8610 - val_loss: 0.5612 - val_accuracy: 0.7581
# Epoch 6/20
# 24/24 [==============================] - 8s 340ms/step - loss: 0.2854 - accuracy: 0.9091 - val_loss: 0.5819 - val_accuracy: 0.7849
# Epoch 7/20
# 24/24 [==============================] - 7s 309ms/step - loss: 0.1998 - accuracy: 0.9345 - val_loss: 0.4797 - val_accuracy: 0.7903
# Epoch 8/20
# 24/24 [==============================] - 7s 305ms/step - loss: 0.1564 - accuracy: 0.9545 - val_loss: 0.6149 - val_accuracy: 0.8118
# Epoch 9/20
# 24/24 [==============================] - 7s 279ms/step - loss: 0.0898 - accuracy: 0.9652 - val_loss: 0.6775 - val_accuracy: 0.8333
# Epoch 10/20
# 24/24 [==============================] - 7s 292ms/step - loss: 0.1016 - accuracy: 0.9679 - val_loss: 0.5781 - val_accuracy: 0.8333
# Epoch 11/20
# 24/24 [==============================] - 7s 290ms/step - loss: 0.0636 - accuracy: 0.9826 - val_loss: 0.6291 - val_accuracy: 0.8441
# Epoch 12/20
# 24/24 [==============================] - 7s 275ms/step - loss: 0.0369 - accuracy: 0.9893 - val_loss: 0.5342 - val_accuracy: 0.8333
# Epoch 13/20
# 24/24 [==============================] - 7s 274ms/step - loss: 0.0162 - accuracy: 0.9987 - val_loss: 0.5688 - val_accuracy: 0.8763
# Epoch 14/20
# 24/24 [==============================] - 7s 281ms/step - loss: 0.0105 - accuracy: 0.9973 - val_loss: 0.5992 - val_accuracy: 0.8763
# Epoch 15/20
# 24/24 [==============================] - 7s 278ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.6889 - val_accuracy: 0.8817
# Epoch 16/20
# 24/24 [==============================] - 7s 276ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.7178 - val_accuracy: 0.8817
# Epoch 17/20
# 24/24 [==============================] - 7s 289ms/step - loss: 9.3582e-04 - accuracy: 1.0000 - val_loss: 0.7396 - val_accuracy: 0.8871
# Epoch 18/20
# 24/24 [==============================] - 7s 295ms/step - loss: 6.9612e-04 - accuracy: 1.0000 - val_loss: 0.7330 - val_accuracy: 0.8871
# Epoch 19/20
# 24/24 [==============================] - 7s 283ms/step - loss: 6.5085e-04 - accuracy: 1.0000 - val_loss: 0.7757 - val_accuracy: 0.8710
# Epoch 20/20
# 24/24 [==============================] - 7s 280ms/step - loss: 5.5544e-04 - accuracy: 1.0000 - val_loss: 0.7409 - val_accuracy: 0.8871

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/nw/1nf_xk7d24jb7_5w54x0g9fh0000gn/T/ipykernel_9201/2405672729.py in <module>
# ----> 1 acc = model['accuracy']
#       2 val_acc = model['val_accuracy']
#       3
#       4 loss = model['loss']
#       5 val_loss = model['val_loss']
#
# TypeError: 'Sequential' object is not subscriptable

# %%
model.evaluate(test_ds)
# Out:
# 10/10 [==============================] - 1s 88ms/step - loss: 3.7743 - accuracy: 0.5933
# [3.7743489742279053, 0.5933333039283752]

# %%
upload = "images/perfect.jpg"

img = tf.keras.utils.load_img(
    upload, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) 

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7faa095b0dd0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7faa095b0dd0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1/1 [==============================] - 0s 84ms/step
# This image most likely belongs to perfect with a 100.00 percent confidence.

# %%
upload = "images/what.jpg"

img = tf.keras.utils.load_img(
    upload, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) 

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# This image most likely belongs to shoo with a 55.00 percent confidence.

# %%
upload = "images/shoo.jpg"

img = tf.keras.utils.load_img(
    upload, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) 

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# This image most likely belongs to shoo with a 99.77 percent confidence.

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faa0a7c84d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faa0a7c84d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faa0aa6c9e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faa0aa6c9e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faa5998e8c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faa5998e8c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faa0ac757a0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faa0ac757a0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faa0adba830> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faa0adba830> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7faa0adba830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faa0ac758c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faa0ac758c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7faa0ac758c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faa0ad82f80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faa0ad82f80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faa0ad82e60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faa0ad82e60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faa092308c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faa092308c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faa09230f80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faa09230f80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faa0adbaa70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faa0adbaa70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faa0adba9e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faa0adba9e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faa09e504d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faa09e504d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faa09e503b0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faa09e503b0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faa08fb09e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faa08fb09e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faa613e2560> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faa613e2560> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faa16678cb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faa16678cb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:AutoGraph could not transform <function pfor.<locals>.f at 0x7faa166788c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function pfor.<locals>.f at 0x7faa166788c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 180, 180, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 90, 90, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  flatten_1 (Flatten)         (None, 30976)             0
#
#  dense_2 (Dense)             (None, 128)               3965056
#
#  dense_3 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 3,989,027
# Trainable params: 3,989,027
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7faa612f5440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7faa612f5440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause has no variant outputs and                           has no vectorized variant inputs
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause has no variant outputs and                           has no vectorized variant inputs
# 24/24 [==============================] - ETA: 0s - loss: 1.2470 - accuracy: 0.4064WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7faa0a0ddb90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7faa0a0ddb90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 24/24 [==============================] - 12s 378ms/step - loss: 1.2470 - accuracy: 0.4064 - val_loss: 1.0187 - val_accuracy: 0.5054
# Epoch 2/15
# 24/24 [==============================] - 9s 380ms/step - loss: 1.0178 - accuracy: 0.4799 - val_loss: 0.8735 - val_accuracy: 0.6720
# Epoch 3/15
# 24/24 [==============================] - 9s 366ms/step - loss: 0.8660 - accuracy: 0.6270 - val_loss: 0.7492 - val_accuracy: 0.6774
# Epoch 4/15
# 24/24 [==============================] - 8s 354ms/step - loss: 0.7834 - accuracy: 0.6578 - val_loss: 0.6220 - val_accuracy: 0.7312
# Epoch 5/15
# 24/24 [==============================] - 8s 352ms/step - loss: 0.6076 - accuracy: 0.7273 - val_loss: 0.5119 - val_accuracy: 0.7957
# Epoch 6/15
# 24/24 [==============================] - 9s 391ms/step - loss: 0.5598 - accuracy: 0.7687 - val_loss: 0.6607 - val_accuracy: 0.6828
# Epoch 7/15
# 24/24 [==============================] - 9s 369ms/step - loss: 0.4905 - accuracy: 0.8075 - val_loss: 0.4157 - val_accuracy: 0.8118
# Epoch 8/15
# 24/24 [==============================] - 9s 359ms/step - loss: 0.3849 - accuracy: 0.8342 - val_loss: 0.4454 - val_accuracy: 0.8387
# Epoch 9/15
# 24/24 [==============================] - 9s 359ms/step - loss: 0.3669 - accuracy: 0.8489 - val_loss: 0.3526 - val_accuracy: 0.8548
# Epoch 10/15
# 24/24 [==============================] - 9s 361ms/step - loss: 0.3041 - accuracy: 0.8810 - val_loss: 0.2630 - val_accuracy: 0.9247
# Epoch 11/15
# 24/24 [==============================] - 9s 357ms/step - loss: 0.2683 - accuracy: 0.9011 - val_loss: 0.2494 - val_accuracy: 0.9032
# Epoch 12/15
# 24/24 [==============================] - 9s 357ms/step - loss: 0.2158 - accuracy: 0.9144 - val_loss: 0.2761 - val_accuracy: 0.8871
# Epoch 13/15
# 24/24 [==============================] - 9s 357ms/step - loss: 0.2090 - accuracy: 0.9211 - val_loss: 0.1889 - val_accuracy: 0.9355
# Epoch 14/15
# 24/24 [==============================] - 9s 355ms/step - loss: 0.1198 - accuracy: 0.9612 - val_loss: 0.1759 - val_accuracy: 0.9462
# Epoch 15/15
# 24/24 [==============================] - 8s 354ms/step - loss: 0.1167 - accuracy: 0.9733 - val_loss: 0.1571 - val_accuracy: 0.9355

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.evaluate(test_ds)
# Out:
# 10/10 [==============================] - 1s 91ms/step - loss: 1.3325 - accuracy: 0.7867
# [1.3324989080429077, 0.7866666913032532]

# %%
upload = "images/perfect.jpg"

img = tf.keras.utils.load_img(
    upload, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) 

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7faa5a52db90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7faa5a52db90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1/1 [==============================] - 0s 87ms/step
# This image most likely belongs to perfect with a 99.66 percent confidence.

# %%
upload = "images/shoo.jpg"

img = tf.keras.utils.load_img(
    upload, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) 

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# This image most likely belongs to perfect with a 68.30 percent confidence.

# %%
upload = "images/what.jpg"

img = tf.keras.utils.load_img(
    upload, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) 

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# This image most likely belongs to perfect with a 98.35 percent confidence.
