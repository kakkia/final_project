# %% [markdown]
# <a href="https://colab.research.google.com/github/kakkia/final_project/blob/main/final_split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image

# %%
training = "/content/drive/MyDrive/data/training"
test = "/content/drive/MyDrive/data/test"

# %%
import pathlib

data = pathlib.Path(training)
test_ds = pathlib.Path(test)

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1175 files belonging to 3 classes.
# Using 940 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1175 files belonging to 3 classes.
# Using 235 files for validation.

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
  test_ds,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 59 files belonging to 3 classes.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['perfect', 'shoo', 'what']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 180, 180, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 3,989,027
# Trainable params: 3,989,027
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 30/30 [==============================] - 74s 594ms/step - loss: 1.5037 - accuracy: 0.3436 - val_loss: 1.0827 - val_accuracy: 0.5149
# Epoch 2/20
# 30/30 [==============================] - 1s 25ms/step - loss: 1.0955 - accuracy: 0.4691 - val_loss: 1.0637 - val_accuracy: 0.5489
# Epoch 3/20
# 30/30 [==============================] - 1s 23ms/step - loss: 0.8870 - accuracy: 0.5745 - val_loss: 0.8252 - val_accuracy: 0.6511
# Epoch 4/20
# 30/30 [==============================] - 1s 23ms/step - loss: 0.5379 - accuracy: 0.7904 - val_loss: 0.5229 - val_accuracy: 0.7957
# Epoch 5/20
# 30/30 [==============================] - 1s 24ms/step - loss: 0.2818 - accuracy: 0.9021 - val_loss: 0.4890 - val_accuracy: 0.8085
# Epoch 6/20
# 30/30 [==============================] - 1s 24ms/step - loss: 0.2477 - accuracy: 0.9330 - val_loss: 0.3671 - val_accuracy: 0.8723
# Epoch 7/20
# 30/30 [==============================] - 1s 24ms/step - loss: 0.1065 - accuracy: 0.9691 - val_loss: 0.3176 - val_accuracy: 0.9021
# Epoch 8/20
# 30/30 [==============================] - 1s 24ms/step - loss: 0.0509 - accuracy: 0.9840 - val_loss: 0.5327 - val_accuracy: 0.8723
# Epoch 9/20
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0646 - accuracy: 0.9777 - val_loss: 0.4652 - val_accuracy: 0.8979
# Epoch 10/20
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0302 - accuracy: 0.9904 - val_loss: 0.4589 - val_accuracy: 0.9106
# Epoch 11/20
# 30/30 [==============================] - 1s 24ms/step - loss: 0.0188 - accuracy: 0.9968 - val_loss: 0.3563 - val_accuracy: 0.9149
# Epoch 12/20
# 30/30 [==============================] - 1s 23ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.5202 - val_accuracy: 0.9149
# Epoch 13/20
# 30/30 [==============================] - 1s 24ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.6188 - val_accuracy: 0.9277
# Epoch 14/20
# 30/30 [==============================] - 1s 24ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.5826 - val_accuracy: 0.9234
# Epoch 15/20
# 30/30 [==============================] - 1s 23ms/step - loss: 7.0313e-04 - accuracy: 1.0000 - val_loss: 0.6263 - val_accuracy: 0.9277
# Epoch 16/20
# 30/30 [==============================] - 1s 24ms/step - loss: 5.4059e-04 - accuracy: 1.0000 - val_loss: 0.6413 - val_accuracy: 0.9277
# Epoch 17/20
# 30/30 [==============================] - 1s 24ms/step - loss: 4.4290e-04 - accuracy: 1.0000 - val_loss: 0.6452 - val_accuracy: 0.9234
# Epoch 18/20
# 30/30 [==============================] - 1s 24ms/step - loss: 3.6327e-04 - accuracy: 1.0000 - val_loss: 0.6648 - val_accuracy: 0.9234
# Epoch 19/20
# 30/30 [==============================] - 1s 24ms/step - loss: 3.0771e-04 - accuracy: 1.0000 - val_loss: 0.6727 - val_accuracy: 0.9234
# Epoch 20/20
# 30/30 [==============================] - 1s 24ms/step - loss: 2.7763e-04 - accuracy: 1.0000 - val_loss: 0.6812 - val_accuracy: 0.9277

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
upload = "/content/drive/MyDrive/data/test/perfect/perfect00703.jpg"

img = tf.keras.utils.load_img(
    upload, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) 

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to perfect with a 99.88 percent confidence.

# %%
upload = "/content/drive/MyDrive/data/test/shoo/shoo00798.jpg"

img = tf.keras.utils.load_img(
    upload, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) 

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to shoo with a 100.00 percent confidence.

# %%
upload = "/content/drive/MyDrive/data/test/what/what00700.jpg"

img = tf.keras.utils.load_img(
    upload, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) 

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to what with a 100.00 percent confidence.

# %%
model.evaluate(test_ds)
# Out:
# 2/2 [==============================] - 7s 177ms/step - loss: 0.7342 - accuracy: 0.8475
# [0.7341597080230713, 0.8474576473236084]

# %%
model.save("final_model")
# Out:
# INFO:tensorflow:Assets written to: final_model/assets

# %%
# data augmentation

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()

# %%
epochs = 15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.evaluate(test_ds)

# %%
upload = "images/perfect.jpg"

img = tf.keras.utils.load_img(
    upload, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) 

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
